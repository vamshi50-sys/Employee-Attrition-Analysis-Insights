# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\LENOVO\Downloads\archive\WA_Fn-UseC_-HR-Employee-Attrition.csv")

# %%
df.info() # By using the df.info() we are here to check whether there any null value in the given dataset
          # we can see the result in console there no null value in the dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
df.duplicated().sum() #Here we are trying to find the duplicate values by using the in built funtion .duplicated()
                # here by add all the by using .sum() we can know the count of duplicate values
# Out:
# np.int64(0)

# %%
df["Age"].dtype #
# Out:
# dtype('int64')

# %% [markdown]
# ### 1. Age Suspicion HR says: “We think young employees leave more.”
# ### Check ONLY:
#
# ### Age distribution
# ### Minimum, maximum, median
# ### How many employees are under 30?
# ### Find whether age could be a suspect.

# %%
df["Age"].value_counts()   # Here we are trying to figuring out no.of people according to the age group
# Out:
# Age
# 35    78
# 34    77
# 36    69
# 31    69
# 29    68
# 32    61
# 30    60
# 38    58
# 33    58
# 40    57
# 37    50
# 28    48
# 27    48
# 42    46
# 39    42
# 45    41
# 41    40
# 26    39
# 44    33
# 46    33
# 43    32
# 50    30
# 25    26
# 24    26
# 49    24
# 47    24
# 55    22
# 48    19
# 51    19
# 53    19
# 54    18
# 52    18
# 22    16
# 56    14
# 58    14
# 23    14
# 21    13
# 20    11
# 59    10
# 19     9
# 18     8
# 60     5
# 57     4
# Name: count, dtype: int64

# %%
# Finding the clues in age column by univarate analysis
maximum = df["Age"].max()
print(maximum)   # Here we are try to figuring out what is the maximum age of a person in given dataset of age column
# Out:
# 60

# %%
minimum = df["Age"].min()
print(minimum)    # Here we are try to figuring out what is the minimum age of a person in given dataset of age column
# Out:
# 18

# %%
median = df["Age"].median()
print(median)   
print(minimum)    # Here we are try to figuring out what is the median age of a person in given dataset of age column
# Out:
# 36.0
# 18

# %%
mask = df["Age"]<30
df["Age"][mask].value_counts() # Here we found that people age under 30 --- how many of them in their respective age group
# Out:
# Age
# 29    68
# 27    48
# 28    48
# 26    39
# 25    26
# 24    26
# 22    16
# 23    14
# 21    13
# 20    11
# 19     9
# 18     8
# Name: count, dtype: int64

# %% [markdown]
# ### 2. Income Mystery : Finance team believes members with lower income are unhappy.
#
# ### Your task:
#
# ### Check average, median, quartiles of MonthlyIncome.
# ### Is income skewed? – describe()
# ### Do you see many employees earning at the lower end

# %%
mean = df["MonthlyIncome"].mean().round(3)
print(mean)      # In the second question we are checking out the mean value of monthlyincome column 
                 # so that we can know the average income of the group
# Out:
# 6502.931

# %%
median = df["MonthlyIncome"].median()
print(median)
# Out:
# 4919.0

# %%
df["MonthlyIncome"].describe()
# Out:
# count     1470.000000
# mean      6502.931293
# std       4707.956783
# min       1009.000000
# 25%       2911.000000
# 50%       4919.000000
# 75%       8379.000000
# max      19999.000000
# Name: MonthlyIncome, dtype: float64

# %%
print("the quartiles of MonthlyIncome at 25% is ",df["MonthlyIncome"].describe()["25%"])
print("the quartiles of MonthlyIncome at 50% is ",df["MonthlyIncome"].describe()["50%"])
print("the quartiles of MonthlyIncome at 75% is ",df["MonthlyIncome"].describe()["75%"])
# Out:
# the quartiles of MonthlyIncome at 25% is  2911.0
# the quartiles of MonthlyIncome at 50% is  4919.0
# the quartiles of MonthlyIncome at 75% is  8379.0

# %%
# is income skewed? – describe()

# here we figure out that data of MonthlyIncome is skewed towards rightside so it positive skew

# %%
mask1 = df["MonthlyIncome"]< mean
df["MonthlyIncome"][mask1].value_counts()   # here we are found that no.of persons MonthlyIncome of employees 
                                            # earning at the lower end which below the mean(average)
# Out:
# MonthlyIncome
# 2342    4
# 2741    3
# 3452    3
# 2610    3
# 2559    3
#        ..
# 3785    1
# 2966    1
# 2571    1
# 5390    1
# 3944    1
# Name: count, Length: 865, dtype: int64

# %% [markdown]
# ### 3. Distance-from-Home Rumor
#
# ### Someone said: "People who live far leave the company."
#
# ### Check percentiles of DistanceFromHome.
# ### Identify if there are many long commuters. → quantile | skewness

# %%
df["DistanceFromHome"].describe()
# Out:
# count    1470.000000
# mean        9.192517
# std         8.106864
# min         1.000000
# 25%         2.000000
# 50%         7.000000
# 75%        14.000000
# max        29.000000
# Name: DistanceFromHome, dtype: float64

# %%
print("the percentiles of DistanceFromHome 25% ",df["DistanceFromHome"].describe()["25%"])
print("the percentiles of DistanceFromHome 50% ",df["DistanceFromHome"].describe()["50%"])
print("the percentiles of DistanceFromHome 75% ",df["DistanceFromHome"].describe()["75%"])
# Out:
# the percentiles of DistanceFromHome 25%  2.0
# the percentiles of DistanceFromHome 50%  7.0
# the percentiles of DistanceFromHome 75%  14.0

# %%
# Here we identify that most of people are long commuters

# %% [markdown]
# ### 4. OverTime Alarm
#
# ### Count how many people have OverTime = Yes vs No.
# ### Is OverTime common or rare?
# ### This is a major future suspect.

# %%
df["OverTime"].value_counts()
# here most of the people not doing the OverTime
# Out:
# OverTime
# No     1054
# Yes     416
# Name: count, dtype: int64

# %%
# Is OverTime common or rare? 
#  here OverTime is rare because majority of the people don't do OverTime

# %%
# right now we can't say it is a major suspect because most of the people don't do the OverTime 
# more 25%

# %% [markdown]
# ### 5. Job Role Hotspot
#
# ### Find top 3 JobRoles by population.
# ### This tells you where most attrition could happen.

# %%
df["JobRole"].value_counts()
# here we can see that the top 3 jobroles by population are 1. Sales Executive
                                                          # 2. Research Scientist
                                                          # 3. Laboratory Technician
# Out:
# JobRole
# Sales Executive              326
# Research Scientist           292
# Laboratory Technician        259
# Manufacturing Director       145
# Healthcare Representative    131
# Manager                      102
# Sales Representative          83
# Research Director             80
# Human Resources               52
# Name: count, dtype: int64

# %% [markdown]
#  ## BIVARIATE ANALYSIS INTERPRETATION`

# %% [markdown]
# ### 6. The OverTime-Attrition Interrogation
#
# ### HR claims: “OverTime increases Attrition.”
#
# ### Use crosstab with normalize to check if:
# ### Attrition% is higher in OverTime = Yes.

# %%
pd.crosstab(df["OverTime"],df["Attrition"],normalize='index').round(2) 
#pd.crosstab(df["OverTime"],df["Attrition"])
            
# the highest no.of people dont do the OverTime but,
# if you seen the table below the most of people who took the attrition is the one who works OverTime 
# here we can see total people who do OverTime is 416 in this 127 members which is 30% them are quit
# and people who don't do OverTime is 1054 in this 110 member which is 10% of them are quit 
# from this we can say that Attrition % is higher in OverTime  
# Attrition rate is 20 % more than in OverTime
# OverTime looks like a prime suspect. Employees who do overtime have a 45% quitting rate — nearly quadruple the rate of those who don't.
# This suggests workload pressure or burnout.
# Out:
# Attrition    No   Yes
# OverTime
# No         0.90  0.10
# Yes        0.69  0.31

# %% [markdown]
# ### 7. The Travel Conspiracy
#
# ### Managers think frequent travelers quit more.
# ### Use crosstab (normalize row-wise): BusinessTravel vs Attrition
# ### Which travel group seems most suspicious?

# %%
pd.crosstab(df["BusinessTravel"],df["Attrition"])
# Out:
# Attrition           No  Yes
# BusinessTravel
# Non-Travel         138   12
# Travel_Frequently  208   69
# Travel_Rarely      887  156

# %%
# In this analysis, we can understand that there are a total of 1469 persons 
# in these 1469 persons # Travel_Rarely  # Travel_Frequently # Non- Travel
# from the total of 1469 - 237 persons, which is 16% of which 65% --> 156 are attriting, mostly are from the Travel_rarrly group
# The Travel_Rarely group seems more suspicious because maybe they won't get the opportunity to move around like others

# %% [markdown]
# ### 8.The Department Discrepancy
#
# ### Use groupby: Department → mean MonthlyIncome
# ### Which department might be underpaid?
# ### Could that explain Attrition?

# %%
df.groupby(["Department","Attrition"])["MonthlyIncome"].agg(["mean"]).round(2)
# Out:
#                                      mean
# Department             Attrition
# Human Resources        No         7345.98
#                        Yes        3715.75
# Research & Development No         6630.33
#                        Yes        4108.08
# Sales                  No         7232.24
#                        Yes        5908.46

# %%
# In the above analysis, we can find a pattern.
# A possible reason behind this pattern is that the people leaving the organisation is they are underpaid. 
# Why are they underpaid? And the difference is almost 50% in each department, so it should be figured out

# %% [markdown]
# ### 9. Gender Bias Check
#
# ### Check:
# ## Gender vs Attrition (crosstab %)
# ### Is there any surprising bias?

# %%
pd.crosstab(df["Gender"],df["Attrition"])
# Out:
# Attrition   No  Yes
# Gender
# Female     501   87
# Male       732  150

# %%
# In the above analysis, we can see that there are nearly 20% of people leaving in both groups 
# It's almost the same percentage, so nothing surprising bias

# %% [markdown]
# ### 10. JobSatisfaction Leak
#
# ### Check average JobSatisfaction per JobRole.
# ### Which JobRole has lowest satisfaction?
# ### Possible motive for quitting.

# %%
pd.crosstab(df["JobRole"],df["JobSatisfaction"])
# Out:
# JobSatisfaction             1   2   3    4
# JobRole
# Healthcare Representative  26  19  43   43
# Human Resources            10  16  13   13
# Laboratory Technician      56  48  75   80
# Manager                    21  21  27   33
# Manufacturing Director     26  32  49   38
# Research Director          15  16  27   22
# Research Scientist         54  53  90   95
# Sales Executive            69  54  91  112
# Sales Representative       12  21  27   23

# %%
# In the above average jobsatisfaction per jobrole we can see the pattern that in every JobRole, there is an average 16 - 20% JobSatifaction level of 1
# From this we can know that there is a very good chance These people can Attrirate

# %%
df.groupby("JobRole")["JobSatisfaction"].mean()
# Out:
# JobRole
# Healthcare Representative    2.786260
# Human Resources              2.557692
# Laboratory Technician        2.691120
# Manager                      2.705882
# Manufacturing Director       2.682759
# Research Director            2.700000
# Research Scientist           2.773973
# Sales Executive              2.754601
# Sales Representative         2.734940
# Name: JobSatisfaction, dtype: float64

# %% [markdown]
# ### MULTIVARIATE ANALYSIS

# %% [markdown]
# ### 11. Triple Threat Case
#
# ### People say Attrition happens when Age is low, Income is low, and Satisfaction is low.
#
# ### Use filtering:
# ### Age < 30
# ### MonthlyIncome < median
# ### JobSatisfaction < median
# ### How many such “high risk” employees exist?

# %%
df[(df["Age"]<30) & (df["MonthlyIncome"]<df["MonthlyIncome"].median()) & (df["JobSatisfaction"]<df["JobSatisfaction"].median())]
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 4      27        No      Travel_Rarely        591  Research & Development
# 41     27        No      Travel_Rarely       1240  Research & Development
# 71     29        No      Travel_Rarely       1328  Research & Development
# 86     23        No      Travel_Rarely        541                   Sales
# 125    26        No      Travel_Rarely        841  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1411   25        No      Travel_Rarely        309         Human Resources
# 1436   21        No      Travel_Rarely        501                   Sales
# 1438   23       Yes  Travel_Frequently        638                   Sales
# 1459   29        No      Travel_Rarely       1378  Research & Development
# 1460   29        No      Travel_Rarely        468  Research & Development
#
#       DistanceFromHome  Education    EducationField  EmployeeCount  \
# ...

# %%
(106/1470)*100
# Out:
# 7.210884353741497

# %%
arr = np.where((df["Age"]<30) & (df["MonthlyIncome"]<df["MonthlyIncome"].median()) & (df["JobSatisfaction"]<df["JobSatisfaction"].median()),"triple","others")

# %%
pd.crosstab(arr,df["Attrition"],normalize="index").round(2)
# Out:
# Attrition    No   Yes
# row_0
# others     0.85  0.15
# triple     0.64  0.36

# %%
# In here we can find people with low income, the least jobSatisfaction and age below 30 is only 7%

# The combination of Age and MonthlyIncome,JobSatisfaction, along with Attrition 
# this significantly increased to 21 % by subtracting triple treat with others 
# With this analysis we can know that when income is low, jobsatisfaction is low in people below 30 leaves the Organization

# %% [markdown]
# ### 12. Department x JobRole Investigation
#
# ### Group by: Department, JobRole → Attrition count
#
# ### Which combinations show high exits?

# %%
df.groupby(["Department","JobRole"])["Attrition"].value_counts()
# Out:
# Department              JobRole                    Attrition
# Human Resources         Human Resources            No            40
#                                                    Yes           12
#                         Manager                    No            11
# Research & Development  Healthcare Representative  No           122
#                                                    Yes            9
#                         Laboratory Technician      No           197
#                                                    Yes           62
#                         Manager                    No            51
#                                                    Yes            3
#                         Manufacturing Director     No           135
#                                                    Yes           10
#                         Research Director          No            78
#                                                    Yes            2
# ...

# %%
# Here after doing some analysis by groupby and value_counts, we found that the highest attritions is in 
# Research & Development - Labortory Technician ---> 62
#                          Research Scientist ---> 47
# Sales - Sales Executive   --> 57 
#         Sales Representative --> 33 
# HR - HR --> 12
# These are HotSpots we can in this analysis 
# The combination we can find high in Research & Development X Laboratory Technician

# %% [markdown]
# ### 13. Salary Ladder Case
#
# ### Use pivot table:
# ### JobLevel × EducationField → mean MonthlyIncome
# ### Which combination earns the most
# ### Which earns the least?
# ### This reveals potential compensation unfairness.

# %%
# The combination that earns the most is in EducationField X TechnicalDegree in JobLevel = "5" --- 19573
# The combination that earns the least is in EducationField X Human Resources in JobLevel = "1" --- 2564
# "Yes" This reveals potential compensation and unfairness is seen in the JobLevel '1' and '4' is around 15%

# %% [markdown]
# ### 14. The Long Commute Problem
#
# ### Multivariate check:
# ### DistanceFromHome + OverTime + Attrition
#
# ### Find:
# ### Among employees who do OverTime AND live > 10 km, how many left?
# ### This is detective-level bivariate + filter logic.

# %%
df[ (df["OverTime"] == "Yes") & (df["DistanceFromHome"]>10) & (df["Attrition"]=="Yes")].shape
# Out:
# (55, 35)

# %%
(55/1470)*100
# Out:
# 3.741496598639456

# %%
# In total no.of employees who do OverTime and live > 10km raidus and left the organization are 55 members 
# which is 3.7% of total members

# %% [markdown]
# ### 15. Lifestyle Breakdown Case
#
# ### Group by Department:
#
# ### Avg WorkLifeBalance
# ### Avg JobSatisfaction
# ### Attrition count
# ### Which department seems “stressful”?

# %%
pd.pivot_table(df,index=["Department"],values=["WorkLifeBalance","JobSatisfaction"],aggfunc="mean").round(2)
# Out:
#                         JobSatisfaction  WorkLifeBalance
# Department
# Human Resources                    2.60             2.92
# Research & Development             2.73             2.73
# Sales                              2.75             2.82

# %%
pd.crosstab(df["Department"],df["Attrition"])
# Out:
# Attrition                No  Yes
# Department
# Human Resources          51   12
# Research & Development  828  133
# Sales                   354   92

# %%
# Lifestyle Breakdown Case
# Avg WorkLifeBalance
# Avg JobSatisfaction
# Attrition count
# by all this department the stressful on is the Research & Development because it has more no.of Attrition 133 which is 16%

# %% [markdown]
# ### FINAL SUSPECT IDENTIFICATION

# %%
# 16. Who are the top 3 strongest suspects causing Attrition?


# The first strongest suspect causing Attrition is OverTime because people are leaving more than 25%  
# THE second strongest suspect causing Attrition is Potential compensation, the difference between JobLevel 1 and 4 
# and Unfairness, which is 15%
# The third Strongest suspect causing Attrition is  people with low Income and people with low Satisfaction level is 7%

# %%
#  17. Which groups of employees face the highest quitting risk

# the groups of employees face the highest quitting risk is :
# Sales Representatives and Laboratory Technicians
# younger employees age less than 30 years
# Lower-income level 
# Low JobSatisfaction scores are 1–2

# %%
# 18. Which department needs immediate HR intervention? Why?

# The department needs immediate HR intervention is Sales Representatives and Laboratory Technicians shows the highest attrition rates.
# Lower-income level individuals face a higher quitting risk.
# When MonthlyIncome is below the median, attrition percentages of Attrition rises significantly.

# %%
# 19. What patterns suggest workload issues?

# the patterns suggest workload issues is OverTime and Attrition
# WorkLifeBalance ratings of low level 1 and 2
# lowSatisfaction in specific roles 
# below 30 aged and lower income people

# %%
# 20. Give 5 actionable recommendations based on your investigation.

# addressing the Overtime and workload issue by redistributing the workload 
# improve the Jobsatisfaction level by conducting surveys and taking feedbacks from the employees
# Mentoring the younger people 
# by increasing wages based on the performance
# maintaining the worklifebalance by offer wellness programs and flexiable work timings and by monitoring the wellsness of employess
